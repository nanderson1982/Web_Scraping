# %% [markdown]
# # Web Scraping - UFC.com

# %% [markdown]
# ## Notebook Setup

# %%
# Import libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from pprint import pprint

# %% [markdown]
# ## Get Event URLs

# %%
# UFC Completed events URL to be scraped
events_completed_url = "http://www.ufcstats.com/statistics/events/completed?page=all"

# %%
def get_table_body(url: str):
    """Send get request to url to get html text and find the table on the webpage."""
    
    # Send get request to URL provided
    page = requests.get(url)

    # Return the html text of the page
    soup = bs(page.text, 'lxml')

    # Find the table of data on the page 
    table_body = soup.find('table')
    
    return table_body, soup

# %%
# Get the table HTML from the webpage
table_body, _ = get_table_body(events_completed_url)

# %%
def get_event_links(table_body):
    """Create a list of web links to all completed UFC events."""
    
    event_links = []

    for row in table_body.find_all('tr'):
        cols = row.find_all('td')
        for col in cols:
            a_tag = col.find('a')
            if a_tag:
                event = a_tag['href']
                event_links.append(event)
                
    return event_links

# %%
# Create list of web links
event_links = get_event_links(table_body)
len(event_links)
# Out:
# 641

# %% [markdown]
# ## Get Event Details

# %%
# URL to be scraped --> Will be loop
event_link = event_links[1]

# %%
# Get the table HTML from the webpage
table_body, soup = get_table_body(event_link)
print(table_body)
# Out:
# <table class="b-fight-details__table b-fight-details__table_style_margin-top b-fight-details__table_type_event-details js-fight-table" style="display: table;">
# <thead class="b-fight-details__table-head">
# <tr class="b-fight-details__table-row">
# <th class="b-fight-details__table-col">
#     W/L
#   </th>
# <th class="b-fight-details__table-col l-page_align_left">
#     Fighter
#   </th>
# <th class="b-fight-details__table-col">
#     Kd
#   </th>
# <th class="b-fight-details__table-col">
#     Str
#   </th>
# <th class="b-fight-details__table-col">
#     Td
#   </th>
# <th class="b-fight-details__table-col">
#     Sub
#   </th>
# <th class="b-fight-details__table-col l-page_align_left">
#     Weight class
#   </th>
# <th class="b-fight-details__table-col l-page_align_left">
#     Method
#   </th>
# <th class="b-fight-details__table-col">
#     Round
#   </th>
# <th class="b-fight-details__table-col">
#     Time
#   </th>
# </tr>
# </thead>
# <tbody class="b-fight-details__table-body">
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/33fa6793a7f984ac" onclick="doNav('http://www.ufcstats.com/fight-details/33fa6793a7f984ac')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/33fa6793a7f984ac"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/65f09bacd3957381">
#               Cory Sandhagen
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/7c7332319c14094c">
#               Marlon Vera
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                128
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             58
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             3
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Bantamweight<br/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         S-DEC
#
#       </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         5
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         5:00
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/1c2d0db1c9eed052" onclick="doNav('http://www.ufcstats.com/fight-details/1c2d0db1c9eed052')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/1c2d0db1c9eed052"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/634e2fb70bde3fd5">
#               Holly Holm
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/3143bf892608139a">
#               Yana Santos
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                32
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             21
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             4
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Women's Bantamweight<br/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         U-DEC
#
#       </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         3
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         5:00
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/bce8ece2ff26b4d4" onclick="doNav('http://www.ufcstats.com/fight-details/bce8ece2ff26b4d4')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/bce8ece2ff26b4d4"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/583ee11abddfc581">
#               Nate Landwehr
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/305d73ede05e31ad">
#               Austin Lingo
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                64
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             48
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Featherweight<br/>
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/perf.png" style="margin-right:2px;"/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         SUB
#
#       </p>
# <p class="b-fight-details__table-text">
#         Rear Naked Choke
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         2
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         4:11
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/9433730f95d52fc8" onclick="doNav('http://www.ufcstats.com/fight-details/9433730f95d52fc8')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/9433730f95d52fc8"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/6a740daf1b279661">
#               Maycee Barber
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/05fa626cb33d15b8">
#               Andrea Lee
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                48
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             39
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             2
#           </p>
# <p class="b-fight-details__table-text">
#
#             5
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Women's Flyweight<br/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         S-DEC
#
#       </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         3
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         5:00
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/2f382615155e32b9" onclick="doNav('http://www.ufcstats.com/fight-details/2f382615155e32b9')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/2f382615155e32b9"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/6b7c7460855dbbb9">
#               Albert Duraev
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/c68c68efaa5ca6ef">
#               Chidi Njokuani
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                45
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             40
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             2
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Middleweight<br/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         S-DEC
#
#       </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         3
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         5:00
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/c6cc6ae23cbf8a27" onclick="doNav('http://www.ufcstats.com/fight-details/c6cc6ae23cbf8a27')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/c6cc6ae23cbf8a27"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/361d49960a196976">
#               Daniel Pineda
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/7832f2f62f04178f">
#               Tucker Lutz
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                24
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             28
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             2
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Featherweight<br/>
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/perf.png" style="margin-right:2px;"/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         SUB
#
#       </p>
# <p class="b-fight-details__table-text">
#         Guillotine Choke
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         2
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         2:50
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/b9e037a45f8850fb" onclick="doNav('http://www.ufcstats.com/fight-details/b9e037a45f8850fb')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/b9e037a45f8850fb"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/11583163f45c7b31">
#               Lucas Alexander
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/b93c06d09d1c4ac0">
#               Steven Peterson
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                85
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             26
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Featherweight<br/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         U-DEC
#
#       </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         3
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         5:00
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/07e39fd5f4f23270" onclick="doNav('http://www.ufcstats.com/fight-details/07e39fd5f4f23270')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/07e39fd5f4f23270"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/b27a1fcb56a3035a">
#               Trevin Giles
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/9fe7af8b3fbe00a0">
#               Preston Parsons
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                55
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             42
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             3
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             3
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Welterweight<br/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         S-DEC
#
#       </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         3
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         5:00
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/16bd47ba50891833" onclick="doNav('http://www.ufcstats.com/fight-details/16bd47ba50891833')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/16bd47ba50891833"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/077e3ace32b72be9">
#               CJ Vergara
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/31bb0772f21cabd8">
#               Daniel Lacerda
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             2
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                83
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             48
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# <p class="b-fight-details__table-text">
#
#             2
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Flyweight<br/>
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/fight.png" style="margin-right:2px;"/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         KO/TKO
#
#       </p>
# <p class="b-fight-details__table-text">
#         Elbows
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         2
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         4:04
#       </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://www.ufcstats.com/fight-details/6f6fec9c78244174" onclick="doNav('http://www.ufcstats.com/fight-details/6f6fec9c78244174')">
# <td class="b-fight-details__table-col b-fight-details__table-col_style_align-top">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://www.ufcstats.com/fight-details/6f6fec9c78244174"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# <br/>
# </td>
# <td class="b-fight-details__table-col l-page_align_left" style="width:100px">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/dc7927cd622676a7">
#               Victor Altamirano
#             </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/fighter-details/65cdf4ec31143d86">
#               Vinicius Salvador
#             </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#                62
#
#           </p>
# <p class="b-fight-details__table-text">
#
#
#             47
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             3
#           </p>
# <p class="b-fight-details__table-text">
#
#             1
#           </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# <p class="b-fight-details__table-text">
#
#             0
#           </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#         Flyweight<br/>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#         U-DEC
#
#       </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#
#         3
#       </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#         5:00
#       </p>
# </td>
# </tr>
# </tbody>
# </table>

# %%
row_data = []

for row in table_body.find_all('tr'):
    col = row.find_all('td')
    col = [ele.text.strip() for ele in col]
    print(col)
# Out:
# []
# ['win', 'Cory Sandhagen\n            \n\n\n\n              Marlon Vera', '0\n          \n\n            \n            0', '128\n\n          \n\n\n            \n            58', '3\n          \n\n            \n            0', '0\n          \n\n            \n            1', 'Bantamweight', 'S-DEC', '5', '5:00']
# ['win', 'Holly Holm\n            \n\n\n\n              Yana Santos', '0\n          \n\n            \n            0', '32\n\n          \n\n\n            \n            21', '4\n          \n\n            \n            0', '0\n          \n\n            \n            0', "Women's Bantamweight", 'U-DEC', '3', '5:00']
# ['win', 'Nate Landwehr\n            \n\n\n\n              Austin Lingo', '0\n          \n\n            \n            0', '64\n\n          \n\n\n            \n            48', '1\n          \n\n            \n            0', '1\n          \n\n            \n            0', 'Featherweight', 'SUB\n\n      \n\n        Rear Naked Choke', '2', '4:11']
# ['win', 'Maycee Barber\n            \n\n\n\n              Andrea Lee', '0\n          \n\n            \n            0', '48\n\n          \n\n\n            \n            39', '2\n          \n\n            \n            5', '0\n          \n\n            \n            0', "Women's Flyweight", 'S-DEC', '3', '5:00']
# ['win', 'Albert Duraev\n            \n\n\n\n              Chidi Njokuani', '0\n          \n\n            \n            0', '45\n\n          \n\n\n            \n            40', '2\n          \n\n            \n            0', '0\n          \n\n            \n            0', 'Middleweight', 'S-DEC', '3', '5:00']
# ['win', 'Daniel Pineda\n            \n\n\n\n              Tucker Lutz', '1\n          \n\n            \n            0', '24\n\n          \n\n\n            \n            28', '1\n          \n\n            \n            0', '2\n          \n\n            \n            0', 'Featherweight', 'SUB\n\n      \n\n        Guillotine Choke', '2', '2:50']
# ['win', 'Lucas Alexander\n            \n\n\n\n              Steven Peterson', '1\n          \n\n            \n            0', '85\n\n          \n\n\n            \n            26', '0\n          \n\n            \n            0', '0\n          \n\n            \n            0', 'Featherweight', 'U-DEC', '3', '5:00']
# ['win', 'Trevin Giles\n            \n\n\n\n              Preston Parsons', '0\n          \n\n            \n            0', '55\n\n          \n\n\n            \n            42', '0\n          \n\n            \n            3', '0\n          \n\n            \n            3', 'Welterweight', 'S-DEC', '3', '5:00']
# ['win', 'CJ Vergara\n            \n\n\n\n              Daniel Lacerda', '0\n          \n\n            \n            2', '83\n\n          \n\n\n            \n            48', '0\n          \n\n            \n            1', '1\n          \n\n            \n            2', 'Flyweight', 'KO/TKO\n\n      \n\n        Elbows', '2', '4:04']
# ['win', 'Victor Altamirano\n            \n\n\n\n              Vinicius Salvador', '0\n          \n\n            \n            0', '62\n\n          \n\n\n            \n            47', '3\n          \n\n            \n            1', '0\n          \n\n            \n            0', 'Flyweight', 'U-DEC', '3', '5:00']

# %%
# Find the 'td' element containing the names
names_td = soup.select_one('.l-page_align_left[style="width:100px"]')

# Extract the names from the 'a' elements
names = [a.get_text(strip=True) for a in names_td.find_all('a')]

# Find the 'td' elements containing the stats
stats_tds = soup.select('.b-fight-details__table-col:not(.l-page_align_left)')

# Extract the stats from the 'p' elements in each 'td'
stats = [[p.get_text(strip=True) for p in td.find_all('p')] for td in stats_tds]

# Combine the names and stats into a dictionary
data = {}
for i, name in enumerate(names):
    data[name] = [stat[i] if len(stat) > i else '' for stat in stats]

from pprint import pprint
pprint(data)
# Out:
# {'Cory Sandhagen': ['',
#                     '',
#                     '',
#                     '',
#                     '',
#                     '',
#                     '',
#                     'win',
#                     '0',
#                     '128',
#                     '3',
#                     '0',
#                     '5',
#                     '5:00',
#                     'win',
#                     '0',
#                     '32',
#                     '4',
#                     '0',
#                     '3',
#                     '5:00',
#                     'win',
#                     '0',
#                     '64',
#                     '1',
#                     '1',
#                     '2',
#                     '4:11',
#                     'win',
#                     '0',
#                     '48',
#                     '2',
#                     '0',
#                     '3',
#                     '5:00',
#                     'win',
#                     '0',
#                     '45',
#                     '2',
#                     '0',
#                     '3',
#                     '5:00',
#                     'win',
#                     '1',
#                     '24',
#                     '1',
#                     '2',
#                     '2',
#                     '2:50',
#                     'win',
#                     '1',
#                     '85',
#                     '0',
#                     '0',
#                     '3',
#                     '5:00',
#                     'win',
#                     '0',
#                     '55',
#                     '0',
#                     '0',
#                     '3',
#                     '5:00',
#                     'win',
#                     '0',
#                     '83',
#                     '0',
#                     '1',
#                     '2',
#                     '4:04',
#                     'win',
#                     '0',
#                     '62',
#                     '3',
#                     '0',
#                     '3',
#                     '5:00'],
#  'Marlon Vera': ['',
#                  '',
#                  '',
#                  '',
#                  '',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '58',
#                  '0',
#                  '1',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '21',
#                  '0',
#                  '0',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '48',
#                  '0',
#                  '0',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '39',
#                  '5',
#                  '0',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '40',
#                  '0',
#                  '0',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '28',
#                  '0',
#                  '0',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '26',
#                  '0',
#                  '0',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '42',
#                  '3',
#                  '3',
#                  '',
#                  '',
#                  '',
#                  '2',
#                  '48',
#                  '1',
#                  '2',
#                  '',
#                  '',
#                  '',
#                  '0',
#                  '47',
#                  '1',
#                  '0',
#                  '',
#                  '']}

# %%
# Find all rows
rows = soup.find_all('tr')

# Iterate over each row
results = []
for row in rows:
    row_data = {}
    tds = row.find_all('td')

    # Check if the row has enough columns
    if len(tds) < 10:
        continue
    
    # Extract names
    names_td = tds[1]
    names = [a.get_text(strip=True) for a in names_td.find_all('a')]
    row_data['names'] = names
    
    # Extract stats
    stats_tds = tds[2:6]
    stats = [[p.get_text(strip=True) for p in td.find_all('p')] for td in stats_tds]
    row_data['stats'] = {name: [stat[i] for stat in stats] for i, name in enumerate(names)}

    # Extract weight class
    weight_class_td = tds[6]
    weight_class = weight_class_td.get_text(strip=True)
    row_data['weight_class'] = weight_class

    # Extract method
    method_td = tds[7]
    method = method_td.get_text(strip=True)
    row_data['method'] = method

    # Extract round and time
    round_td, time_td = tds[8:]
    row_data['round'] = round_td.get_text(strip=True)
    row_data['time'] = time_td.get_text(strip=True)
    
    results.append(row_data)

for result in results:
    print(result)
# Out:
# {'names': ['Cory Sandhagen', 'Marlon Vera'], 'stats': {'Cory Sandhagen': ['0', '128', '3', '0'], 'Marlon Vera': ['0', '58', '0', '1']}, 'weight_class': 'Bantamweight', 'method': 'S-DEC', 'round': '5', 'time': '5:00'}
# {'names': ['Holly Holm', 'Yana Santos'], 'stats': {'Holly Holm': ['0', '32', '4', '0'], 'Yana Santos': ['0', '21', '0', '0']}, 'weight_class': "Women's Bantamweight", 'method': 'U-DEC', 'round': '3', 'time': '5:00'}
# {'names': ['Nate Landwehr', 'Austin Lingo'], 'stats': {'Nate Landwehr': ['0', '64', '1', '1'], 'Austin Lingo': ['0', '48', '0', '0']}, 'weight_class': 'Featherweight', 'method': 'SUBRear Naked Choke', 'round': '2', 'time': '4:11'}
# {'names': ['Maycee Barber', 'Andrea Lee'], 'stats': {'Maycee Barber': ['0', '48', '2', '0'], 'Andrea Lee': ['0', '39', '5', '0']}, 'weight_class': "Women's Flyweight", 'method': 'S-DEC', 'round': '3', 'time': '5:00'}
# {'names': ['Albert Duraev', 'Chidi Njokuani'], 'stats': {'Albert Duraev': ['0', '45', '2', '0'], 'Chidi Njokuani': ['0', '40', '0', '0']}, 'weight_class': 'Middleweight', 'method': 'S-DEC', 'round': '3', 'time': '5:00'}
# {'names': ['Daniel Pineda', 'Tucker Lutz'], 'stats': {'Daniel Pineda': ['1', '24', '1', '2'], 'Tucker Lutz': ['0', '28', '0', '0']}, 'weight_class': 'Featherweight', 'method': 'SUBGuillotine Choke', 'round': '2', 'time': '2:50'}
# {'names': ['Lucas Alexander', 'Steven Peterson'], 'stats': {'Lucas Alexander': ['1', '85', '0', '0'], 'Steven Peterson': ['0', '26', '0', '0']}, 'weight_class': 'Featherweight', 'method': 'U-DEC', 'round': '3', 'time': '5:00'}
# {'names': ['Trevin Giles', 'Preston Parsons'], 'stats': {'Trevin Giles': ['0', '55', '0', '0'], 'Preston Parsons': ['0', '42', '3', '3']}, 'weight_class': 'Welterweight', 'method': 'S-DEC', 'round': '3', 'time': '5:00'}
# {'names': ['CJ Vergara', 'Daniel Lacerda'], 'stats': {'CJ Vergara': ['0', '83', '0', '1'], 'Daniel Lacerda': ['2', '48', '1', '2']}, 'weight_class': 'Flyweight', 'method': 'KO/TKOElbows', 'round': '2', 'time': '4:04'}
# {'names': ['Victor Altamirano', 'Vinicius Salvador'], 'stats': {'Victor Altamirano': ['0', '62', '3', '0'], 'Vinicius Salvador': ['0', '47', '1', '0']}, 'weight_class': 'Flyweight', 'method': 'U-DEC', 'round': '3', 'time': '5:00'}
